# %%
# Importing required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '2025_Problem_C_Data/summerOly_medal_counts_utf8.csv'
df = pd.read_csv(file_path)

# %%
df
# Out:
#       Rank                   NOC  Gold  Silver  Bronze  Total  Year
# 0        1         United States    11       7       2     20  1896
# 1        2                Greece    10      18      19     47  1896
# 2        3               Germany     6       5       2     13  1896
# 3        4                France     5       4       2     11  1896
# 4        5         Great Britain     2       3       2      7  1896
# ...    ...                   ...   ...     ...     ...    ...   ...
# 1430    84                 Qatar     0       0       1      1  2024
# 1431    84  Refugee Olympic Team     0       0       1      1  2024
# 1432    84             Singapore     0       0       1      1  2024
# 1433    84              Slovakia     0       0       1      1  2024
# 1434    84                Zambia     0       0       1      1  2024
#
# [1435 rows x 7 columns]

# %%
pivot_data = df.pivot(index='Year', columns='NOC', values='Total').fillna(0)
pivot_data
pivot_data.to_csv('pivot_data.csv', index=True)

# %%
# Plot
plt.figure(figsize=(14, 8))

# Plot a line for each country
for country in pivot_data.columns:
    plt.plot(pivot_data.index, pivot_data[country], label=country, alpha=0.7)

plt.title("Medal Trends Over Time by Country", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Number of Medals", fontsize=14)
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/57/f1b6dp4j2g96pfwxt0xskpxr0000gn/T/ipykernel_10495/3887171609.py:13: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Step 1: Filter data for the last five Olympic years
last_five_years = [2000, 2004, 2008, 2012, 2016]  # Adjust as necessary
pivot_data_last_five_years = pivot_data.loc[last_five_years]

# Step 2: Extract actual data for 2024
actual_2024_data = pivot_data.loc[2024]  # Assuming 2024 data exists in pivot_data

# Step 3: Train linear regression models for each country
regressor = LinearRegression()
predictions_2024 = {}  # Store predictions

# Features (years) and reshape for sklearn
X = np.array(last_five_years).reshape(-1, 1)  # Independent variable (years)

for country in pivot_data.columns:
    # Medal counts for the last five years for the current country
    y = pivot_data_last_five_years[country].values
    
    # Train a linear regression model
    regressor.fit(X, y)
    
    # Predict medal count for 2024
    predictions_2024[country] = regressor.predict([[2024]])[0]

# Step 4: Compare predictions with actual 2024 data
# Convert predictions and actual data to Series for easier alignment
predicted_2024 = pd.Series(predictions_2024)
predicted_2024 = predicted_2024.clip(lower=0)
actual_2024 = actual_2024_data

# Ensure alignment of indices
aligned_actual = actual_2024[actual_2024.index.isin(predicted_2024.index)]
aligned_predicted = predicted_2024[aligned_actual.index]

# Step 5: Calculate Mean Squared Error (MSE)
mse = mean_squared_error(aligned_actual, aligned_predicted)
print(f"Mean Squared Error (MSE) for 2024 predictions: {mse:.2f}")

# Display predictions vs actual data
comparison = pd.DataFrame({
    "Predicted": aligned_predicted,
    "Actual": aligned_actual
})
print(comparison)
# Out:
# Mean Squared Error (MSE) for 2024 predictions: 39.22
#                 Predicted  Actual
# NOC
# Afghanistan           0.8     0.0
# Albania               0.0     2.0
# Algeria               0.0     3.0
# Argentina             4.0     3.0
# Armenia               5.6     4.0
# ...                   ...     ...
# Virgin Islands        0.0     0.0
# West Germany          0.0     0.0
# Yugoslavia            0.0     0.0
# Zambia                0.0     1.0
# Zimbabwe              0.2     0.0
#
# [164 rows x 2 columns]

# %%
# Step 1: Create a bar plot
x = np.arange(len(aligned_actual))  # Positions for each country on the x-axis
width = 0.4  # Width of the bars

plt.figure(figsize=(14, 8))

# Plot predicted and actual counts
plt.bar(x - width / 2, aligned_predicted, width, label="Predicted", color='blue', alpha=0.7)
plt.bar(x + width / 2, aligned_actual, width, label="Actual", color='orange', alpha=0.7)

# Step 2: Add labels and title
plt.title("Predicted vs Actual Medal Counts by Country (2024)", fontsize=16)
plt.xlabel("Country", fontsize=14)
plt.ylabel("Medal Count", fontsize=14)
plt.xticks(x, aligned_actual.index, rotation=90, fontsize=10)  # Country names on x-axis
plt.legend(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Step 3: Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
# Testing the number of athlete vs. total medal counts

athlete = pd.read_csv('2025_Problem_C_Data/summerOly_athletes_utf8.csv')

# %%
athlete.columns
# Out:
# Index(['Name', 'Sex', 'Team', 'NOC', 'Year', 'City', 'Sport', 'Event',
#        'Medal'],
#       dtype='object')

# %%
athlete.loc[athlete['NOC'] == 'AIN', 'NOC'] = 'RUS'
athlete.loc[athlete['NOC'] == 'RUS', 'Team'] = 'Russia'

# %%
# Group the athletes data by country ('team') and year to count the number of athletes per country per year
athletes_per_country_year = athlete.groupby(['Team', 'Year']).size().reset_index(name='Num_Athletes')

# Merge the athlete data with the medal counts data for years prior to 2024
historical_data = df[df['Year'] < 2024]  # Filter for years before 2024
merged_data = pd.merge(athletes_per_country_year, historical_data[['NOC', 'Year', 'Total']], left_on=['Team', 'Year'], right_on=['NOC', 'Year'])

# %%
merged_data
# Out:
#              Team  Year  Num_Athletes          NOC  Total
# 0     Afghanistan  2008             4  Afghanistan      1
# 1     Afghanistan  2012             6  Afghanistan      1
# 2         Algeria  1984            33      Algeria      2
# 3         Algeria  1992            36      Algeria      2
# 4         Algeria  1996            47      Algeria      3
# ...           ...   ...           ...          ...    ...
# 1317       Zambia  1984            18       Zambia      1
# 1318       Zambia  1996             8       Zambia      1
# 1319     Zimbabwe  1980            52     Zimbabwe      1
# 1320     Zimbabwe  2004            14     Zimbabwe      3
# 1321     Zimbabwe  2008            16     Zimbabwe      4
#
# [1322 rows x 5 columns]

# %%
# Step 1: Filter the historical data for the last five Olympic years (2000, 2004, 2008, 2012, 2016)
last_five_years = [2000, 2004, 2008, 2012, 2016]
athletes_per_country_year = athlete.groupby(['Team', 'Year']).size().reset_index(name='Num_Athletes')

# Filter the medal counts data for the last five years
historical_data = df[df['Year'].isin(last_five_years)]

# Step 2: Merge the athlete data with the medal counts data
merged_data = pd.merge(athletes_per_country_year, historical_data[['NOC', 'Year', 'Total']], on=['Team', 'Year'])

# Step 3: Train the linear regression model using the last 5 years' data
X = merged_data[['Num_Athletes']]  # Number of athletes as feature
y = merged_data['Total']  # Total medals as target

# Initialize and train the linear regression model
regressor = LinearRegression()
regressor.fit(X, y)

# Step 4: Make predictions for 2024 using the number of athletes for 2024
athletes_2024 = athletes_per_country_year[athletes_per_country_year['Year'] == 2024]
X_2024 = athletes_2024[['Num_Athletes']]  # Number of athletes for 2024
predicted_medals_2024 = regressor.predict(X_2024)

# Add the predictions to the dataframe
athletes_2024['Predicted_Medals_2024'] = predicted_medals_2024

# Display the predictions
print(athletes_2024[['Team', 'Num_Athletes', 'Predicted_Medals_2024']])

# Step 5: Compare predictions with actual 2024 data (if available)
# Assuming actual_2024_data contains actual medal counts for 2024:
# You need the actual data for 2024 to calculate the Mean Squared Error (MSE)
actual_2024_data = df[df['Year'] == 2024][['NOC', 'Total']]

# Merge predictions with actual data
comparison = pd.merge(athletes_2024, actual_2024_data, left_on='Team', right_on='NOC', how='left')
comparison
# Calculate the Mean Squared Error (MSE)
#mse = mean_squared_error(comparison['Total'], comparison['Predicted_Medals_2024'])
#print(f"Mean Squared Error (MSE) for 2024 medal predictions: {mse:.2f}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/57/f1b6dp4j2g96pfwxt0xskpxr0000gn/T/ipykernel_10495/2355243064.py in ?()
#       5 # Filter the medal counts data for the last five years
#       6 historical_data = df[df['Year'].isin(last_five_years)]
#       7
#       8 # Step 2: Merge the athlete data with the medal counts data
# ----> 9 merged_data = pd.merge(athletes_per_country_year, historical_data[['NOC', 'Year', 'Total']], on=['Team', 'Year'])
#      10
#      11 # Step 3: Train the linear regression model using the last 5 years' data
#      12 X = merged_data[['Num_Athletes']]  # Number of athletes as feature
#
# ~/myenv/lib/python3.12/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
# ...

# %%
print(f"Linear regression equation: Total medals = {slope:.2f} * Num_Athletes + {intercept:.2f}")
# Out:
# Linear regression equation: Total medals = 0.11 * Num_Athletes + -4.40

# %%
# Filter the athlete dataset for 2024 to get the number of athletes for each country
athletes_2024 = athlete[athlete['Year'] == 2024]
athletes_2024_count = athletes_2024.groupby('Team').size().reset_index(name='Num_Athletes')

# Make predictions for 2024 using the trained model
X_2024 = athletes_2024_count[['Num_Athletes']]  # Number of athletes for 2024
predicted_medals_2024 = model.predict(X_2024)  # Predicted total medals for 2024

# Add the predictions to the DataFrame
athletes_2024_count['Predicted_Medals_2024'] = np.maximum(predicted_medals_2024, 0)

# Display the top rows to verify
print(athletes_2024_count.head())
# Out:
#              Team  Num_Athletes  Predicted_Medals_2024
# 0     Afghanistan             7               0.000000
# 1         Albania             9               0.000000
# 2         Algeria            55               1.620211
# 3  American Samoa             2               0.000000
# 4         Andorra             4               0.000000

# %%
# Step 1: Get the actual medal counts for 2024
actual_medals_2024 = df[df['Year'] == 2024][['NOC', 'Total']]

# Step 2: Merge predicted data with the actual medal counts
# Merge on 'team' (from athletes_2024_count) and 'NOC' (from medal_counts) to align countries
comparison = pd.merge(athletes_2024_count, actual_medals_2024, left_on='Team', right_on='NOC', how='left')

# Step 3: Create the plot (Bar plot)
import matplotlib.pyplot as plt

# Set up positions for the bars
x = np.arange(len(comparison))  # Number of countries
width = 0.4  # Bar width

# Create the bar plot
plt.figure(figsize=(14, 8))

# Plot predicted and actual medal counts
plt.bar(x - width / 2, comparison['Predicted_Medals_2024'], width, label="Predicted", color='blue', alpha=0.7)
plt.bar(x + width / 2, comparison['Total'], width, label="Actual", color='orange', alpha=0.7)

# Add labels and title
plt.title("Predicted vs Actual Medal Counts for 2024", fontsize=16)
plt.xlabel("Country", fontsize=14)
plt.ylabel("Medal Count", fontsize=14)
plt.xticks(x, comparison['Team'], rotation=90, fontsize=10)  # Country names on x-axis
plt.legend(fontsize=12)

# Add grid for y-axis to improve readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
# Check for NaN values in the input and target variables
print(athletes_2024_count.isnull().sum())  # Check for missing values in features
print(df.isnull().sum())  # Check for missing values in actual medal counts

# Option 1: Drop rows with NaN values (if feasible)
athletes_2024_count = athletes_2024_count.dropna()

# Option 2: Impute missing values (if needed, e.g., replacing NaNs with the mean)
athletes_2024_count.fillna(athletes_2024_count.mean(), inplace=True)

# Similarly, you can handle NaN values in the actual_medals_2024 DataFrame
actual_medals_2024 = actual_medals_2024.dropna()  # Drop rows with NaN values

# After handling NaNs, you can continue with the merging and model fitting
comparison = pd.merge(athletes_2024_count, actual_medals_2024, left_on='Team', right_on='NOC', how='left')

# Check if there are any remaining NaN values in the comparison DataFrame
print(comparison.isnull().sum())
# Out:
# Team                     0
# Num_Athletes             0
# Predicted_Medals_2024    0
# dtype: int64
# Rank      0
# NOC       0
# Gold      0
# Silver    0
# Bronze    0
# Total     0
# Year      0
# dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 9
#       6 athletes_2024_count = athletes_2024_count.dropna()
#       8 # Option 2: Impute missing values (if needed, e.g., replacing NaNs with the mean)
# ----> 9 athletes_2024_count.fillna(athletes_2024_count.mean(), inplace=True)
#      11 # Similarly, you can handle NaN values in the actual_medals_2024 DataFrame
#      12 actual_medals_2024 = actual_medals_2024.dropna()  # Drop rows with NaN values
#
# File ~/myenv/lib/python3.12/site-packages/pandas/core/frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
# ...
